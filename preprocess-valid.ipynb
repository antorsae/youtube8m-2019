# %%
import numpy as np 
import pandas as pd
from fastai.data_block import get_files
from fastprogress import master_bar, progress_bar
import tensorflow as tf
import torch 
import os
import pickle

# %%
IN_PATH  = 'yt8m/3/frame/validate'
OUT_PATH = 'yt8m-processed'

files = [str(f) for f in get_files(IN_PATH, '.tfrecord')]
files
# Out:
# ['yt8m/3/frame/validate/validate1032.tfrecord',
#  'yt8m/3/frame/validate/validate2324.tfrecord',
#  'yt8m/3/frame/validate/validate2351.tfrecord',
#  'yt8m/3/frame/validate/validate3253.tfrecord',
#  'yt8m/3/frame/validate/validate2328.tfrecord',
#  'yt8m/3/frame/validate/validate3697.tfrecord',
#  'yt8m/3/frame/validate/validate1343.tfrecord',
#  'yt8m/3/frame/validate/validate0468.tfrecord',
#  'yt8m/3/frame/validate/validate2820.tfrecord',
#  'yt8m/3/frame/validate/validate1076.tfrecord',
#  'yt8m/3/frame/validate/validate0155.tfrecord',
#  'yt8m/3/frame/validate/validate1981.tfrecord',
#  'yt8m/3/frame/validate/validate2442.tfrecord',
#  'yt8m/3/frame/validate/validate1389.tfrecord',
#  'yt8m/3/frame/validate/validate1376.tfrecord',
#  'yt8m/3/frame/validate/validate2468.tfrecord',
#  'yt8m/3/frame/validate/validate1112.tfrecord',
#  'yt8m/3/frame/validate/validate0205.tfrecord',
#  'yt8m/3/frame/validate/validate2948.tfrecord',
#  'yt8m/3/frame/validate/validate0033.tfrecord',
#  'yt8m/3/frame/validate/validate1497.tfrecord',
#  'yt8m/3/frame/validate/validate3786.tfrecord',
#  'yt8m/3/frame/validate/validate2475.tfrecord',
#  'yt8m/3/frame/validate/validate2346.tfrecord',
#  'yt8m/3/frame/validate/validate0773.tfrecord',
#  'yt8m/3/frame/validate/validate1209.tfrecord',
#  'yt8m/3/frame/validate/validate0641.tfrecord',
#  'yt8m/3/frame/validate/validate2800.tfrecord',
#  'yt8m/3/frame/validate/validate3201.tfrecord',
#  'yt8m/3/frame/validate/validate0417.tfrecord',
#  'yt8m/3/frame/validate/validate3574.tfrecord',
#  'yt8m/3/frame/validate/validate2845.tfrecord',
#  'yt8m/3/frame/validate/validate2687.tfrecord',
#  'yt8m/3/frame/validate/validate1807.tfrecord',
#  'yt8m/3/frame/validate/validate2460.tfrecord',
#  'yt8m/3/frame/validate/validate1292.tfrecord',
#  'yt8m/3/frame/validate/validate0345.tfrecord',
#  'yt8m/3/frame/validate/validate1326.tfrecord',
#  'yt8m/3/frame/validate/validate1641.tfrecord',
#  'yt8m/3/frame/validate/validate0007.tfrecord',
#  'yt8m/3/frame/validate/validate1877.tfrecord',
#  'yt8m/3/frame/validate/validate2670.tfrecord',
#  'yt8m/3/frame/validate/validate0278.tfrecord',
#  'yt8m/3/frame/validate/validate2754.tfrecord',
#  'yt8m/3/frame/validate/validate2527.tfrecord',
#  'yt8m/3/frame/validate/validate2766.tfrecord',
#  'yt8m/3/frame/validate/validate0185.tfrecord',
#  'yt8m/3/frame/validate/validate0279.tfrecord',
#  'yt8m/3/frame/validate/validate0020.tfrecord',
#  'yt8m/3/frame/validate/validate1185.tfrecord',
#  'yt8m/3/frame/validate/validate3356.tfrecord',
#  'yt8m/3/frame/validate/validate0629.tfrecord',
#  'yt8m/3/frame/validate/validate2286.tfrecord',
#  'yt8m/3/frame/validate/validate0477.tfrecord',
#  'yt8m/3/frame/validate/validate1135.tfrecord',
#  'yt8m/3/frame/validate/validate2569.tfrecord',
#  'yt8m/3/frame/validate/validate2789.tfrecord',
#  'yt8m/3/frame/validate/validate3381.tfrecord',
#  'yt8m/3/frame/validate/validate0948.tfrecord',
#  'yt8m/3/frame/validate/validate0863.tfrecord',
#  'yt8m/3/frame/validate/validate1217.tfrecord',
#  'yt8m/3/frame/validate/validate0479.tfrecord',
#  'yt8m/3/frame/validate/validate3377.tfrecord',
#  'yt8m/3/frame/validate/validate3533.tfrecord',
#  'yt8m/3/frame/validate/validate2716.tfrecord',
#  'yt8m/3/frame/validate/validate2809.tfrecord',
#  'yt8m/3/frame/validate/validate0363.tfrecord',
#  'yt8m/3/frame/validate/validate0432.tfrecord',
#  'yt8m/3/frame/validate/validate0041.tfrecord',
#  'yt8m/3/frame/validate/validate2624.tfrecord',
#  'yt8m/3/frame/validate/validate1881.tfrecord',
#  'yt8m/3/frame/validate/validate0121.tfrecord',
#  'yt8m/3/frame/validate/validate3587.tfrecord',
#  'yt8m/3/frame/validate/validate0006.tfrecord',
#  'yt8m/3/frame/validate/validate1474.tfrecord',
#  'yt8m/3/frame/validate/validate3067.tfrecord',
#  'yt8m/3/frame/validate/validate2187.tfrecord',
#  'yt8m/3/frame/validate/validate2577.tfrecord',
#  'yt8m/3/frame/validate/validate1096.tfrecord',
#  'yt8m/3/frame/validate/validate2287.tfrecord',
#  'yt8m/3/frame/validate/validate3662.tfrecord',
#  'yt8m/3/frame/validate/validate0648.tfrecord',
#  'yt8m/3/frame/validate/validate1098.tfrecord',
#  'yt8m/3/frame/validate/validate2769.tfrecord',
#  'yt8m/3/frame/validate/validate1117.tfrecord',
#  'yt8m/3/frame/validate/validate3427.tfrecord',
#  'yt8m/3/frame/validate/validate1211.tfrecord',
#  'yt8m/3/frame/validate/validate0444.tfrecord',
#  'yt8m/3/frame/validate/validate2278.tfrecord',
#  'yt8m/3/frame/validate/validate3221.tfrecord',
#  'yt8m/3/frame/validate/validate0763.tfrecord',
#  'yt8m/3/frame/validate/validate2846.tfrecord',
#  'yt8m/3/frame/validate/validate1723.tfrecord',
#  'yt8m/3/frame/validate/validate1138.tfrecord',
#  'yt8m/3/frame/validate/validate2277.tfrecord',
#  'yt8m/3/frame/validate/validate2031.tfrecord',
#  'yt8m/3/frame/validate/validate1488.tfrecord',
#  'yt8m/3/frame/validate/validate0418.tfrecord',
#  'yt8m/3/frame/validate/validate1588.tfrecord',
#  'yt8m/3/frame/validate/validate3069.tfrecord',
#  'yt8m/3/frame/validate/validate2261.tfrecord',
#  'yt8m/3/frame/validate/validate3223.tfrecord',
#  'yt8m/3/frame/validate/validate3054.tfrecord',
#  'yt8m/3/frame/validate/validate0337.tfrecord',
#  'yt8m/3/frame/validate/validate2039.tfrecord',
#  'yt8m/3/frame/validate/validate3837.tfrecord',
#  'yt8m/3/frame/validate/validate3764.tfrecord',
#  'yt8m/3/frame/validate/validate3481.tfrecord',
#  'yt8m/3/frame/validate/validate2840.tfrecord',
#  'yt8m/3/frame/validate/validate2420.tfrecord',
#  'yt8m/3/frame/validate/validate3820.tfrecord',
#  'yt8m/3/frame/validate/validate0621.tfrecord',
#  'yt8m/3/frame/validate/validate0111.tfrecord',
#  'yt8m/3/frame/validate/validate2409.tfrecord',
#  'yt8m/3/frame/validate/validate0147.tfrecord',
#  'yt8m/3/frame/validate/validate2749.tfrecord',
#  'yt8m/3/frame/validate/validate3443.tfrecord',
#  'yt8m/3/frame/validate/validate0911.tfrecord',
#  'yt8m/3/frame/validate/validate1953.tfrecord',
#  'yt8m/3/frame/validate/validate1762.tfrecord',
#  'yt8m/3/frame/validate/validate0511.tfrecord',
#  'yt8m/3/frame/validate/validate1178.tfrecord',
#  'yt8m/3/frame/validate/validate3200.tfrecord',
#  'yt8m/3/frame/validate/validate1451.tfrecord',
#  'yt8m/3/frame/validate/validate2501.tfrecord',
#  'yt8m/3/frame/validate/validate0913.tfrecord',
#  'yt8m/3/frame/validate/validate3412.tfrecord',
#  'yt8m/3/frame/validate/validate1731.tfrecord',
#  'yt8m/3/frame/validate/validate2603.tfrecord',
#  'yt8m/3/frame/validate/validate0615.tfrecord',
#  'yt8m/3/frame/validate/validate3104.tfrecord',
#  'yt8m/3/frame/validate/validate3312.tfrecord',
#  'yt8m/3/frame/validate/validate2149.tfrecord',
#  'yt8m/3/frame/validate/validate1224.tfrecord',
#  'yt8m/3/frame/validate/validate1387.tfrecord',
#  'yt8m/3/frame/validate/validate1747.tfrecord',
#  'yt8m/3/frame/validate/validate0107.tfrecord',
#  'yt8m/3/frame/validate/validate2627.tfrecord',
#  'yt8m/3/frame/validate/validate3224.tfrecord',
#  'yt8m/3/frame/validate/validate3163.tfrecord',
#  'yt8m/3/frame/validate/validate2398.tfrecord',
#  'yt8m/3/frame/validate/validate3121.tfrecord',
#  'yt8m/3/frame/validate/validate0706.tfrecord',
#  'yt8m/3/frame/validate/validate3744.tfrecord',
#  'yt8m/3/frame/validate/validate3798.tfrecord',
#  'yt8m/3/frame/validate/validate2904.tfrecord',
#  'yt8m/3/frame/validate/validate0315.tfrecord',
#  'yt8m/3/frame/validate/validate2023.tfrecord',
#  'yt8m/3/frame/validate/validate3101.tfrecord',
#  'yt8m/3/frame/validate/validate1606.tfrecord',
#  'yt8m/3/frame/validate/validate1527.tfrecord',
#  'yt8m/3/frame/validate/validate3071.tfrecord',
#  'yt8m/3/frame/validate/validate0377.tfrecord',
#  'yt8m/3/frame/validate/validate2980.tfrecord',
#  'yt8m/3/frame/validate/validate2077.tfrecord',
#  'yt8m/3/frame/validate/validate1811.tfrecord',
#  'yt8m/3/frame/validate/validate0370.tfrecord',
#  'yt8m/3/frame/validate/validate3457.tfrecord',
#  'yt8m/3/frame/validate/validate3047.tfrecord',
#  'yt8m/3/frame/validate/validate0320.tfrecord',
#  'yt8m/3/frame/validate/validate3113.tfrecord',
#  'yt8m/3/frame/validate/validate0806.tfrecord',
#  'yt8m/3/frame/validate/validate2136.tfrecord',
#  'yt8m/3/frame/validate/validate0116.tfrecord',
#  'yt8m/3/frame/validate/validate2950.tfrecord',
#  'yt8m/3/frame/validate/validate1038.tfrecord',
#  'yt8m/3/frame/validate/validate1834.tfrecord',
#  'yt8m/3/frame/validate/validate1512.tfrecord',
#  'yt8m/3/frame/validate/validate2084.tfrecord',
#  'yt8m/3/frame/validate/validate0406.tfrecord',
#  'yt8m/3/frame/validate/validate3191.tfrecord',
#  'yt8m/3/frame/validate/validate1331.tfrecord',
#  'yt8m/3/frame/validate/validate1383.tfrecord',
#  'yt8m/3/frame/validate/validate1299.tfrecord',
#  'yt8m/3/frame/validate/validate3722.tfrecord',
#  'yt8m/3/frame/validate/validate1696.tfrecord',
#  'yt8m/3/frame/validate/validate1703.tfrecord',
#  'yt8m/3/frame/validate/validate0397.tfrecord',
#  'yt8m/3/frame/validate/validate0984.tfrecord',
#  'yt8m/3/frame/validate/validate1306.tfrecord',
#  'yt8m/3/frame/validate/validate0049.tfrecord',
#  'yt8m/3/frame/validate/validate3839.tfrecord',
#  'yt8m/3/frame/validate/validate3730.tfrecord',
#  'yt8m/3/frame/validate/validate1973.tfrecord',
#  'yt8m/3/frame/validate/validate0838.tfrecord',
#  'yt8m/3/frame/validate/validate2016.tfrecord',
#  'yt8m/3/frame/validate/validate1708.tfrecord',
#  'yt8m/3/frame/validate/validate3537.tfrecord',
#  'yt8m/3/frame/validate/validate3551.tfrecord',
#  'yt8m/3/frame/validate/validate0141.tfrecord',
#  'yt8m/3/frame/validate/validate0949.tfrecord',
#  'yt8m/3/frame/validate/validate3419.tfrecord',
#  'yt8m/3/frame/validate/validate0521.tfrecord',
#  'yt8m/3/frame/validate/validate3398.tfrecord',
#  'yt8m/3/frame/validate/validate1345.tfrecord',
#  'yt8m/3/frame/validate/validate3129.tfrecord',
#  'yt8m/3/frame/validate/validate1247.tfrecord',
#  'yt8m/3/frame/validate/validate3138.tfrecord',
#  'yt8m/3/frame/validate/validate1674.tfrecord',
#  'yt8m/3/frame/validate/validate3679.tfrecord',
#  'yt8m/3/frame/validate/validate2220.tfrecord',
#  'yt8m/3/frame/validate/validate2812.tfrecord',
#  'yt8m/3/frame/validate/validate0144.tfrecord',
#  'yt8m/3/frame/validate/validate0529.tfrecord',
#  'yt8m/3/frame/validate/validate2042.tfrecord',
#  'yt8m/3/frame/validate/validate3490.tfrecord',
#  'yt8m/3/frame/validate/validate3647.tfrecord',
#  'yt8m/3/frame/validate/validate3832.tfrecord',
#  'yt8m/3/frame/validate/validate3773.tfrecord',
#  'yt8m/3/frame/validate/validate0089.tfrecord',
#  'yt8m/3/frame/validate/validate1176.tfrecord',
#  'yt8m/3/frame/validate/validate3143.tfrecord',
#  'yt8m/3/frame/validate/validate3558.tfrecord',
#  'yt8m/3/frame/validate/validate1384.tfrecord',
#  'yt8m/3/frame/validate/validate2067.tfrecord',
#  'yt8m/3/frame/validate/validate0189.tfrecord',
#  'yt8m/3/frame/validate/validate0082.tfrecord',
#  'yt8m/3/frame/validate/validate3166.tfrecord',
#  'yt8m/3/frame/validate/validate1481.tfrecord',
#  'yt8m/3/frame/validate/validate3333.tfrecord',
#  'yt8m/3/frame/validate/validate0614.tfrecord',
#  'yt8m/3/frame/validate/validate0221.tfrecord',
#  'yt8m/3/frame/validate/validate1017.tfrecord',
#  'yt8m/3/frame/validate/validate2523.tfrecord',
#  'yt8m/3/frame/validate/validate2924.tfrecord',
#  'yt8m/3/frame/validate/validate1507.tfrecord',
#  'yt8m/3/frame/validate/validate1318.tfrecord',
#  'yt8m/3/frame/validate/validate2695.tfrecord',
#  'yt8m/3/frame/validate/validate1016.tfrecord',
#  'yt8m/3/frame/validate/validate1891.tfrecord',
#  'yt8m/3/frame/validate/validate0297.tfrecord',
#  'yt8m/3/frame/validate/validate2483.tfrecord',
#  'yt8m/3/frame/validate/validate1046.tfrecord',
#  'yt8m/3/frame/validate/validate3748.tfrecord',
#  'yt8m/3/frame/validate/validate3258.tfrecord',
#  'yt8m/3/frame/validate/validate3618.tfrecord',
#  'yt8m/3/frame/validate/validate2402.tfrecord',
#  'yt8m/3/frame/validate/validate3025.tfrecord',
#  'yt8m/3/frame/validate/validate0106.tfrecord',
#  'yt8m/3/frame/validate/validate2799.tfrecord',
#  'yt8m/3/frame/validate/validate2480.tfrecord',
#  'yt8m/3/frame/validate/validate1797.tfrecord',
#  'yt8m/3/frame/validate/validate1133.tfrecord',
#  'yt8m/3/frame/validate/validate3814.tfrecord',
#  'yt8m/3/frame/validate/validate3739.tfrecord',
#  'yt8m/3/frame/validate/validate1218.tfrecord',
#  'yt8m/3/frame/validate/validate1274.tfrecord',
#  'yt8m/3/frame/validate/validate2168.tfrecord',
#  'yt8m/3/frame/validate/validate3315.tfrecord',
#  'yt8m/3/frame/validate/validate2190.tfrecord',
#  'yt8m/3/frame/validate/validate1087.tfrecord',
#  'yt8m/3/frame/validate/validate2747.tfrecord',
#  'yt8m/3/frame/validate/validate3331.tfrecord',
#  'yt8m/3/frame/validate/validate1175.tfrecord',
#  'yt8m/3/frame/validate/validate1120.tfrecord',
#  'yt8m/3/frame/validate/validate2204.tfrecord',
#  'yt8m/3/frame/validate/validate0737.tfrecord',
#  'yt8m/3/frame/validate/validate2362.tfrecord',
#  'yt8m/3/frame/validate/validate3036.tfrecord',
#  'yt8m/3/frame/validate/validate2006.tfrecord',
#  'yt8m/3/frame/validate/validate1298.tfrecord',
#  'yt8m/3/frame/validate/validate2297.tfrecord',
#  'yt8m/3/frame/validate/validate2125.tfrecord',
#  'yt8m/3/frame/validate/validate2051.tfrecord',
#  'yt8m/3/frame/validate/validate2772.tfrecord',
#  'yt8m/3/frame/validate/validate2699.tfrecord',
#  'yt8m/3/frame/validate/validate1816.tfrecord',
#  'yt8m/3/frame/validate/validate0997.tfrecord',
#  'yt8m/3/frame/validate/validate3271.tfrecord',
#  'yt8m/3/frame/validate/validate0864.tfrecord',
#  'yt8m/3/frame/validate/validate0271.tfrecord',
#  'yt8m/3/frame/validate/validate3456.tfrecord',
#  'yt8m/3/frame/validate/validate0792.tfrecord',
#  'yt8m/3/frame/validate/validate1183.tfrecord',
#  'yt8m/3/frame/validate/validate0171.tfrecord',
#  'yt8m/3/frame/validate/validate2034.tfrecord',
#  'yt8m/3/frame/validate/validate2464.tfrecord',
#  'yt8m/3/frame/validate/validate3126.tfrecord',
#  'yt8m/3/frame/validate/validate1083.tfrecord',
#  'yt8m/3/frame/validate/validate0793.tfrecord',
#  'yt8m/3/frame/validate/validate3677.tfrecord',
#  'yt8m/3/frame/validate/validate2490.tfrecord',
#  'yt8m/3/frame/validate/validate0652.tfrecord',
#  'yt8m/3/frame/validate/validate3482.tfrecord',
#  'yt8m/3/frame/validate/validate1845.tfrecord',
#  'yt8m/3/frame/validate/validate3179.tfrecord',
#  'yt8m/3/frame/validate/validate2999.tfrecord',
#  'yt8m/3/frame/validate/validate0769.tfrecord',
#  'yt8m/3/frame/validate/validate0491.tfrecord',
#  'yt8m/3/frame/validate/validate1668.tfrecord',
#  'yt8m/3/frame/validate/validate2400.tfrecord',
#  'yt8m/3/frame/validate/validate2449.tfrecord',
#  'yt8m/3/frame/validate/validate1917.tfrecord',
#  'yt8m/3/frame/validate/validate1431.tfrecord',
#  'yt8m/3/frame/validate/validate3652.tfrecord',
#  'yt8m/3/frame/validate/validate1814.tfrecord',
#  'yt8m/3/frame/validate/validate1414.tfrecord',
#  'yt8m/3/frame/validate/validate0464.tfrecord',
#  'yt8m/3/frame/validate/validate1287.tfrecord',
#  'yt8m/3/frame/validate/validate2358.tfrecord',
#  'yt8m/3/frame/validate/validate2388.tfrecord',
#  'yt8m/3/frame/validate/validate3564.tfrecord',
#  'yt8m/3/frame/validate/validate3526.tfrecord',
#  'yt8m/3/frame/validate/validate0473.tfrecord',
#  'yt8m/3/frame/validate/validate3782.tfrecord',
#  'yt8m/3/frame/validate/validate2608.tfrecord',
#  'yt8m/3/frame/validate/validate1049.tfrecord',
#  'yt8m/3/frame/validate/validate2998.tfrecord',
#  'yt8m/3/frame/validate/validate2808.tfrecord',
#  'yt8m/3/frame/validate/validate2901.tfrecord',
#  'yt8m/3/frame/validate/validate2113.tfrecord',
#  'yt8m/3/frame/validate/validate1208.tfrecord',
#  'yt8m/3/frame/validate/validate2633.tfrecord',
#  'yt8m/3/frame/validate/validate0015.tfrecord',
#  'yt8m/3/frame/validate/validate1700.tfrecord',
#  'yt8m/3/frame/validate/validate3313.tfrecord',
#  'yt8m/3/frame/validate/validate3339.tfrecord',
#  'yt8m/3/frame/validate/validate1970.tfrecord',
#  'yt8m/3/frame/validate/validate0915.tfrecord',
#  'yt8m/3/frame/validate/validate1592.tfrecord',
#  'yt8m/3/frame/validate/validate3737.tfrecord',
#  'yt8m/3/frame/validate/validate0249.tfrecord',
#  'yt8m/3/frame/validate/validate2960.tfrecord',
#  'yt8m/3/frame/validate/validate2582.tfrecord',
#  'yt8m/3/frame/validate/validate1940.tfrecord',
#  'yt8m/3/frame/validate/validate0571.tfrecord',
#  'yt8m/3/frame/validate/validate1738.tfrecord',
#  'yt8m/3/frame/validate/validate1991.tfrecord',
#  'yt8m/3/frame/validate/validate2535.tfrecord',
#  'yt8m/3/frame/validate/validate2265.tfrecord',
#  'yt8m/3/frame/validate/validate2255.tfrecord',
#  'yt8m/3/frame/validate/validate0643.tfrecord',
#  'yt8m/3/frame/validate/validate1869.tfrecord',
#  'yt8m/3/frame/validate/validate3834.tfrecord',
#  'yt8m/3/frame/validate/validate3709.tfrecord',
#  'yt8m/3/frame/validate/validate3716.tfrecord',
#  'yt8m/3/frame/validate/validate2827.tfrecord',
#  'yt8m/3/frame/validate/validate0410.tfrecord',
#  'yt8m/3/frame/validate/validate2502.tfrecord',
#  'yt8m/3/frame/validate/validate2213.tfrecord',
#  'yt8m/3/frame/validate/validate3740.tfrecord',
#  'yt8m/3/frame/validate/validate0335.tfrecord',
#  'yt8m/3/frame/validate/validate0212.tfrecord',
#  'yt8m/3/frame/validate/validate2319.tfrecord',
#  'yt8m/3/frame/validate/validate0605.tfrecord',
#  'yt8m/3/frame/validate/validate1664.tfrecord',
#  'yt8m/3/frame/validate/validate0905.tfrecord',
#  'yt8m/3/frame/validate/validate2752.tfrecord',
#  'yt8m/3/frame/validate/validate1693.tfrecord',
#  'yt8m/3/frame/validate/validate3800.tfrecord',
#  'yt8m/3/frame/validate/validate3074.tfrecord',
#  'yt8m/3/frame/validate/validate0083.tfrecord',
#  'yt8m/3/frame/validate/validate3701.tfrecord',
#  'yt8m/3/frame/validate/validate1094.tfrecord',
#  'yt8m/3/frame/validate/validate3517.tfrecord',
#  'yt8m/3/frame/validate/validate1942.tfrecord',
#  'yt8m/3/frame/validate/validate1715.tfrecord',
#  'yt8m/3/frame/validate/validate3727.tfrecord',
#  'yt8m/3/frame/validate/validate3247.tfrecord',
#  'yt8m/3/frame/validate/validate1443.tfrecord',
#  'yt8m/3/frame/validate/validate1140.tfrecord',
#  'yt8m/3/frame/validate/validate2614.tfrecord',
#  'yt8m/3/frame/validate/validate0350.tfrecord',
#  'yt8m/3/frame/validate/validate1416.tfrecord',
#  'yt8m/3/frame/validate/validate0255.tfrecord',
#  'yt8m/3/frame/validate/validate3426.tfrecord',
#  'yt8m/3/frame/validate/validate0235.tfrecord',
#  'yt8m/3/frame/validate/validate0943.tfrecord',
#  'yt8m/3/frame/validate/validate3666.tfrecord',
#  'yt8m/3/frame/validate/validate0381.tfrecord',
#  'yt8m/3/frame/validate/validate2232.tfrecord',
#  'yt8m/3/frame/validate/validate1897.tfrecord',
#  'yt8m/3/frame/validate/validate0421.tfrecord',
#  'yt8m/3/frame/validate/validate2068.tfrecord',
#  'yt8m/3/frame/validate/validate0216.tfrecord',
#  'yt8m/3/frame/validate/validate2018.tfrecord',
#  'yt8m/3/frame/validate/validate2600.tfrecord',
#  'yt8m/3/frame/validate/validate2184.tfrecord',
#  'yt8m/3/frame/validate/validate1169.tfrecord',
#  'yt8m/3/frame/validate/validate3057.tfrecord',
#  'yt8m/3/frame/validate/validate2575.tfrecord',
#  'yt8m/3/frame/validate/validate0955.tfrecord',
#  'yt8m/3/frame/validate/validate0572.tfrecord',
#  'yt8m/3/frame/validate/validate0000.tfrecord',
#  'yt8m/3/frame/validate/validate0812.tfrecord',
#  'yt8m/3/frame/validate/validate1069.tfrecord',
#  'yt8m/3/frame/validate/validate2310.tfrecord',
#  'yt8m/3/frame/validate/validate3417.tfrecord',
#  'yt8m/3/frame/validate/validate0140.tfrecord',
#  'yt8m/3/frame/validate/validate2590.tfrecord',
#  'yt8m/3/frame/validate/validate2660.tfrecord',
#  'yt8m/3/frame/validate/validate3085.tfrecord',
#  'yt8m/3/frame/validate/validate2905.tfrecord',
#  'yt8m/3/frame/validate/validate1417.tfrecord',
#  'yt8m/3/frame/validate/validate1155.tfrecord',
#  'yt8m/3/frame/validate/validate2996.tfrecord',
#  'yt8m/3/frame/validate/validate3658.tfrecord',
#  'yt8m/3/frame/validate/validate0576.tfrecord',
#  'yt8m/3/frame/validate/validate2355.tfrecord',
#  'yt8m/3/frame/validate/validate0352.tfrecord',
#  'yt8m/3/frame/validate/validate2714.tfrecord',
#  'yt8m/3/frame/validate/validate2533.tfrecord',
#  'yt8m/3/frame/validate/validate2507.tfrecord',
#  'yt8m/3/frame/validate/validate1758.tfrecord',
#  'yt8m/3/frame/validate/validate2298.tfrecord',
#  'yt8m/3/frame/validate/validate0484.tfrecord',
#  'yt8m/3/frame/validate/validate2015.tfrecord',
#  'yt8m/3/frame/validate/validate2943.tfrecord',
#  'yt8m/3/frame/validate/validate1652.tfrecord',
#  'yt8m/3/frame/validate/validate3790.tfrecord',
#  'yt8m/3/frame/validate/validate2322.tfrecord',
#  'yt8m/3/frame/validate/validate3304.tfrecord',
#  'yt8m/3/frame/validate/validate2281.tfrecord',
#  'yt8m/3/frame/validate/validate2597.tfrecord',
#  'yt8m/3/frame/validate/validate3182.tfrecord',
#  'yt8m/3/frame/validate/validate3571.tfrecord',
#  'yt8m/3/frame/validate/validate1002.tfrecord',
#  'yt8m/3/frame/validate/validate2155.tfrecord',
#  'yt8m/3/frame/validate/validate1607.tfrecord',
#  'yt8m/3/frame/validate/validate3711.tfrecord',
#  'yt8m/3/frame/validate/validate1808.tfrecord',
#  'yt8m/3/frame/validate/validate0177.tfrecord',
#  'yt8m/3/frame/validate/validate2966.tfrecord',
#  'yt8m/3/frame/validate/validate0441.tfrecord',
#  'yt8m/3/frame/validate/validate3605.tfrecord',
#  'yt8m/3/frame/validate/validate3034.tfrecord',
#  'yt8m/3/frame/validate/validate2709.tfrecord',
#  'yt8m/3/frame/validate/validate3399.tfrecord',
#  'yt8m/3/frame/validate/validate3127.tfrecord',
#  'yt8m/3/frame/validate/validate1984.tfrecord',
#  'yt8m/3/frame/validate/validate1510.tfrecord',
#  'yt8m/3/frame/validate/validate1756.tfrecord',
#  'yt8m/3/frame/validate/validate2648.tfrecord',
#  'yt8m/3/frame/validate/validate3504.tfrecord',
#  'yt8m/3/frame/validate/validate1048.tfrecord',
#  'yt8m/3/frame/validate/validate1898.tfrecord',
#  'yt8m/3/frame/validate/validate0035.tfrecord',
#  'yt8m/3/frame/validate/validate3501.tfrecord',
#  'yt8m/3/frame/validate/validate3144.tfrecord',
#  'yt8m/3/frame/validate/validate2160.tfrecord',
#  'yt8m/3/frame/validate/validate1754.tfrecord',
#  'yt8m/3/frame/validate/validate2521.tfrecord',
#  'yt8m/3/frame/validate/validate1470.tfrecord',
#  'yt8m/3/frame/validate/validate3404.tfrecord',
#  'yt8m/3/frame/validate/validate3314.tfrecord',
#  'yt8m/3/frame/validate/validate1658.tfrecord',
#  'yt8m/3/frame/validate/validate0458.tfrecord',
#  'yt8m/3/frame/validate/validate3000.tfrecord',
#  'yt8m/3/frame/validate/validate1034.tfrecord',
#  'yt8m/3/frame/validate/validate1403.tfrecord',
#  'yt8m/3/frame/validate/validate0725.tfrecord',
#  'yt8m/3/frame/validate/validate3196.tfrecord',
#  'yt8m/3/frame/validate/validate2788.tfrecord',
#  'yt8m/3/frame/validate/validate1899.tfrecord',
#  'yt8m/3/frame/validate/validate3146.tfrecord',
#  'yt8m/3/frame/validate/validate3107.tfrecord',
#  'yt8m/3/frame/validate/validate0250.tfrecord',
#  'yt8m/3/frame/validate/validate1489.tfrecord',
#  'yt8m/3/frame/validate/validate0324.tfrecord',
#  'yt8m/3/frame/validate/validate0356.tfrecord',
#  'yt8m/3/frame/validate/validate0941.tfrecord',
#  'yt8m/3/frame/validate/validate3577.tfrecord',
#  'yt8m/3/frame/validate/validate0796.tfrecord',
#  'yt8m/3/frame/validate/validate1865.tfrecord',
#  'yt8m/3/frame/validate/validate3004.tfrecord',
#  'yt8m/3/frame/validate/validate0026.tfrecord',
#  'yt8m/3/frame/validate/validate3519.tfrecord',
#  'yt8m/3/frame/validate/validate1236.tfrecord',
#  'yt8m/3/frame/validate/validate1188.tfrecord',
#  'yt8m/3/frame/validate/validate3259.tfrecord',
#  'yt8m/3/frame/validate/validate3342.tfrecord',
#  'yt8m/3/frame/validate/validate2793.tfrecord',
#  'yt8m/3/frame/validate/validate2169.tfrecord',
#  'yt8m/3/frame/validate/validate0051.tfrecord',
#  'yt8m/3/frame/validate/validate2242.tfrecord',
#  'yt8m/3/frame/validate/validate1717.tfrecord',
#  'yt8m/3/frame/validate/validate0800.tfrecord',
#  'yt8m/3/frame/validate/validate3755.tfrecord',
#  'yt8m/3/frame/validate/validate3149.tfrecord',
#  'yt8m/3/frame/validate/validate3781.tfrecord',
#  'yt8m/3/frame/validate/validate3438.tfrecord',
#  'yt8m/3/frame/validate/validate2779.tfrecord',
#  'yt8m/3/frame/validate/validate3154.tfrecord',
#  'yt8m/3/frame/validate/validate3509.tfrecord',
#  'yt8m/3/frame/validate/validate3364.tfrecord',
#  'yt8m/3/frame/validate/validate0781.tfrecord',
#  'yt8m/3/frame/validate/validate0585.tfrecord',
#  'yt8m/3/frame/validate/validate0724.tfrecord',
#  'yt8m/3/frame/validate/validate2702.tfrecord',
#  'yt8m/3/frame/validate/validate3256.tfrecord',
#  'yt8m/3/frame/validate/validate0711.tfrecord',
#  'yt8m/3/frame/validate/validate2314.tfrecord',
#  'yt8m/3/frame/validate/validate3660.tfrecord',
#  'yt8m/3/frame/validate/validate1949.tfrecord',
#  'yt8m/3/frame/validate/validate1901.tfrecord',
#  'yt8m/3/frame/validate/validate1691.tfrecord',
#  'yt8m/3/frame/validate/validate1586.tfrecord',
#  'yt8m/3/frame/validate/validate2551.tfrecord',
#  'yt8m/3/frame/validate/validate0730.tfrecord',
#  'yt8m/3/frame/validate/validate1849.tfrecord',
#  'yt8m/3/frame/validate/validate1938.tfrecord',
#  'yt8m/3/frame/validate/validate0273.tfrecord',
#  'yt8m/3/frame/validate/validate0419.tfrecord',
#  'yt8m/3/frame/validate/validate0430.tfrecord',
#  'yt8m/3/frame/validate/validate0983.tfrecord',
#  'yt8m/3/frame/validate/validate1070.tfrecord',
#  'yt8m/3/frame/validate/validate2520.tfrecord',
#  'yt8m/3/frame/validate/validate2964.tfrecord',
#  'yt8m/3/frame/validate/validate3035.tfrecord',
#  'yt8m/3/frame/validate/validate3596.tfrecord',
#  'yt8m/3/frame/validate/validate0583.tfrecord',
#  'yt8m/3/frame/validate/validate2512.tfrecord',
#  'yt8m/3/frame/validate/validate1181.tfrecord',
#  'yt8m/3/frame/validate/validate2979.tfrecord',
#  'yt8m/3/frame/validate/validate1246.tfrecord',
#  'yt8m/3/frame/validate/validate2307.tfrecord',
#  'yt8m/3/frame/validate/validate2176.tfrecord',
#  'yt8m/3/frame/validate/validate0142.tfrecord',
#  'yt8m/3/frame/validate/validate0286.tfrecord',
#  'yt8m/3/frame/validate/validate1053.tfrecord',
#  'yt8m/3/frame/validate/validate3665.tfrecord',
#  'yt8m/3/frame/validate/validate3508.tfrecord',
#  'yt8m/3/frame/validate/validate0481.tfrecord',
#  'yt8m/3/frame/validate/validate2937.tfrecord',
#  'yt8m/3/frame/validate/validate2862.tfrecord',
#  'yt8m/3/frame/validate/validate2060.tfrecord',
#  'yt8m/3/frame/validate/validate0202.tfrecord',
#  'yt8m/3/frame/validate/validate2241.tfrecord',
#  'yt8m/3/frame/validate/validate1553.tfrecord',
#  'yt8m/3/frame/validate/validate2066.tfrecord',
#  'yt8m/3/frame/validate/validate0740.tfrecord',
#  'yt8m/3/frame/validate/validate3595.tfrecord',
#  'yt8m/3/frame/validate/validate0129.tfrecord',
#  'yt8m/3/frame/validate/validate2974.tfrecord',
#  'yt8m/3/frame/validate/validate0197.tfrecord',
#  'yt8m/3/frame/validate/validate2617.tfrecord',
#  'yt8m/3/frame/validate/validate3629.tfrecord',
#  'yt8m/3/frame/validate/validate0667.tfrecord',
#  'yt8m/3/frame/validate/validate2129.tfrecord',
#  'yt8m/3/frame/validate/validate1737.tfrecord',
#  'yt8m/3/frame/validate/validate3371.tfrecord',
#  'yt8m/3/frame/validate/validate1143.tfrecord',
#  'yt8m/3/frame/validate/validate1472.tfrecord',
#  'yt8m/3/frame/validate/validate3219.tfrecord',
#  'yt8m/3/frame/validate/validate0760.tfrecord',
#  'yt8m/3/frame/validate/validate3233.tfrecord',
#  'yt8m/3/frame/validate/validate2240.tfrecord',
#  'yt8m/3/frame/validate/validate0891.tfrecord',
#  'yt8m/3/frame/validate/validate1303.tfrecord',
#  'yt8m/3/frame/validate/validate0069.tfrecord',
#  'yt8m/3/frame/validate/validate3556.tfrecord',
#  'yt8m/3/frame/validate/validate0098.tfrecord',
#  'yt8m/3/frame/validate/validate3706.tfrecord',
#  'yt8m/3/frame/validate/validate2750.tfrecord',
#  'yt8m/3/frame/validate/validate0951.tfrecord',
#  'yt8m/3/frame/validate/validate0738.tfrecord',
#  'yt8m/3/frame/validate/validate0828.tfrecord',
#  'yt8m/3/frame/validate/validate0560.tfrecord',
#  'yt8m/3/frame/validate/validate2276.tfrecord',
#  'yt8m/3/frame/validate/validate0766.tfrecord',
#  'yt8m/3/frame/validate/validate0456.tfrecord',
#  'yt8m/3/frame/validate/validate2550.tfrecord',
#  'yt8m/3/frame/validate/validate1662.tfrecord',
#  'yt8m/3/frame/validate/validate2868.tfrecord',
#  'yt8m/3/frame/validate/validate0260.tfrecord',
#  'yt8m/3/frame/validate/validate3051.tfrecord',
#  'yt8m/3/frame/validate/validate0776.tfrecord',
#  'yt8m/3/frame/validate/validate1670.tfrecord',
#  'yt8m/3/frame/validate/validate3530.tfrecord',
#  'yt8m/3/frame/validate/validate3723.tfrecord',
#  'yt8m/3/frame/validate/validate2900.tfrecord',
#  'yt8m/3/frame/validate/validate2010.tfrecord',
#  'yt8m/3/frame/validate/validate1418.tfrecord',
#  'yt8m/3/frame/validate/validate0369.tfrecord',
#  'yt8m/3/frame/validate/validate1336.tfrecord',
#  'yt8m/3/frame/validate/validate1018.tfrecord',
#  'yt8m/3/frame/validate/validate2588.tfrecord',
#  'yt8m/3/frame/validate/validate0708.tfrecord',
#  'yt8m/3/frame/validate/validate2711.tfrecord',
#  'yt8m/3/frame/validate/validate0687.tfrecord',
#  'yt8m/3/frame/validate/validate0988.tfrecord',
#  'yt8m/3/frame/validate/validate2893.tfrecord',
#  'yt8m/3/frame/validate/validate3307.tfrecord',
#  'yt8m/3/frame/validate/validate1682.tfrecord',
#  'yt8m/3/frame/validate/validate3393.tfrecord',
#  'yt8m/3/frame/validate/validate3001.tfrecord',
#  'yt8m/3/frame/validate/validate3632.tfrecord',
#  'yt8m/3/frame/validate/validate2524.tfrecord',
#  'yt8m/3/frame/validate/validate1916.tfrecord',
#  'yt8m/3/frame/validate/validate1771.tfrecord',
#  'yt8m/3/frame/validate/validate2649.tfrecord',
#  'yt8m/3/frame/validate/validate0422.tfrecord',
#  'yt8m/3/frame/validate/validate3010.tfrecord',
#  'yt8m/3/frame/validate/validate0431.tfrecord',
#  'yt8m/3/frame/validate/validate0073.tfrecord',
#  'yt8m/3/frame/validate/validate0526.tfrecord',
#  'yt8m/3/frame/validate/validate2856.tfrecord',
#  'yt8m/3/frame/validate/validate2531.tfrecord',
#  'yt8m/3/frame/validate/validate1515.tfrecord',
#  'yt8m/3/frame/validate/validate1435.tfrecord',
#  'yt8m/3/frame/validate/validate1153.tfrecord',
#  'yt8m/3/frame/validate/validate1509.tfrecord',
#  'yt8m/3/frame/validate/validate2234.tfrecord',
#  'yt8m/3/frame/validate/validate2148.tfrecord',
#  'yt8m/3/frame/validate/validate0887.tfrecord',
#  'yt8m/3/frame/validate/validate3752.tfrecord',
#  'yt8m/3/frame/validate/validate1116.tfrecord',
#  'yt8m/3/frame/validate/validate2782.tfrecord',
#  'yt8m/3/frame/validate/validate2291.tfrecord',
#  'yt8m/3/frame/validate/validate2591.tfrecord',
#  'yt8m/3/frame/validate/validate2424.tfrecord',
#  'yt8m/3/frame/validate/validate2447.tfrecord',
#  'yt8m/3/frame/validate/validate2128.tfrecord',
#  'yt8m/3/frame/validate/validate2496.tfrecord',
#  'yt8m/3/frame/validate/validate3796.tfrecord',
#  'yt8m/3/frame/validate/validate1305.tfrecord',
#  'yt8m/3/frame/validate/validate3453.tfrecord',
#  'yt8m/3/frame/validate/validate0896.tfrecord',
#  'yt8m/3/frame/validate/validate2571.tfrecord',
#  'yt8m/3/frame/validate/validate1219.tfrecord',
#  'yt8m/3/frame/validate/validate2229.tfrecord',
#  'yt8m/3/frame/validate/validate2385.tfrecord',
#  'yt8m/3/frame/validate/validate1969.tfrecord',
#  'yt8m/3/frame/validate/validate3234.tfrecord',
#  'yt8m/3/frame/validate/validate3610.tfrecord',
#  'yt8m/3/frame/validate/validate3295.tfrecord',
#  'yt8m/3/frame/validate/validate3432.tfrecord',
#  'yt8m/3/frame/validate/validate3604.tfrecord',
#  'yt8m/3/frame/validate/validate2532.tfrecord',
#  'yt8m/3/frame/validate/validate1950.tfrecord',
#  'yt8m/3/frame/validate/validate1578.tfrecord',
#  'yt8m/3/frame/validate/validate3130.tfrecord',
#  'yt8m/3/frame/validate/validate0638.tfrecord',
#  'yt8m/3/frame/validate/validate3385.tfrecord',
#  'yt8m/3/frame/validate/validate1323.tfrecord',
#  'yt8m/3/frame/validate/validate1831.tfrecord',
#  'yt8m/3/frame/validate/validate2050.tfrecord',
#  'yt8m/3/frame/validate/validate0627.tfrecord',
#  'yt8m/3/frame/validate/validate2844.tfrecord',
#  'yt8m/3/frame/validate/validate1697.tfrecord',
#  'yt8m/3/frame/validate/validate2957.tfrecord',
#  'yt8m/3/frame/validate/validate2784.tfrecord',
#  'yt8m/3/frame/validate/validate0115.tfrecord',
#  'yt8m/3/frame/validate/validate1249.tfrecord',
#  'yt8m/3/frame/validate/validate2458.tfrecord',
#  'yt8m/3/frame/validate/validate2659.tfrecord',
#  'yt8m/3/frame/validate/validate2634.tfrecord',
#  'yt8m/3/frame/validate/validate3650.tfrecord',
#  'yt8m/3/frame/validate/validate3243.tfrecord',
#  'yt8m/3/frame/validate/validate3500.tfrecord',
#  'yt8m/3/frame/validate/validate1728.tfrecord',
#  'yt8m/3/frame/validate/validate3559.tfrecord',
#  'yt8m/3/frame/validate/validate0054.tfrecord',
#  'yt8m/3/frame/validate/validate3265.tfrecord',
#  'yt8m/3/frame/validate/validate2813.tfrecord',
#  'yt8m/3/frame/validate/validate1879.tfrecord',
#  'yt8m/3/frame/validate/validate2133.tfrecord',
#  'yt8m/3/frame/validate/validate2114.tfrecord',
#  'yt8m/3/frame/validate/validate2661.tfrecord',
#  'yt8m/3/frame/validate/validate0215.tfrecord',
#  'yt8m/3/frame/validate/validate0656.tfrecord',
#  'yt8m/3/frame/validate/validate2457.tfrecord',
#  'yt8m/3/frame/validate/validate0677.tfrecord',
#  'yt8m/3/frame/validate/validate1004.tfrecord',
#  'yt8m/3/frame/validate/validate3195.tfrecord',
#  'yt8m/3/frame/validate/validate0816.tfrecord',
#  'yt8m/3/frame/validate/validate0132.tfrecord',
#  'yt8m/3/frame/validate/validate3785.tfrecord',
#  'yt8m/3/frame/validate/validate3167.tfrecord',
#  'yt8m/3/frame/validate/validate2138.tfrecord',
#  'yt8m/3/frame/validate/validate3072.tfrecord',
#  'yt8m/3/frame/validate/validate1251.tfrecord',
#  'yt8m/3/frame/validate/validate3578.tfrecord',
#  'yt8m/3/frame/validate/validate2573.tfrecord',
#  'yt8m/3/frame/validate/validate3451.tfrecord',
#  'yt8m/3/frame/validate/validate2987.tfrecord',
#  'yt8m/3/frame/validate/validate1742.tfrecord',
#  'yt8m/3/frame/validate/validate3292.tfrecord',
#  'yt8m/3/frame/validate/validate0157.tfrecord',
#  'yt8m/3/frame/validate/validate3505.tfrecord',
#  'yt8m/3/frame/validate/validate1057.tfrecord',
#  'yt8m/3/frame/validate/validate0525.tfrecord',
#  'yt8m/3/frame/validate/validate1317.tfrecord',
#  'yt8m/3/frame/validate/validate2755.tfrecord',
#  'yt8m/3/frame/validate/validate1126.tfrecord',
#  'yt8m/3/frame/validate/validate2101.tfrecord',
#  'yt8m/3/frame/validate/validate2945.tfrecord',
#  'yt8m/3/frame/validate/validate3135.tfrecord',
#  'yt8m/3/frame/validate/validate3043.tfrecord',
#  'yt8m/3/frame/validate/validate2217.tfrecord',
#  'yt8m/3/frame/validate/validate3546.tfrecord',
#  'yt8m/3/frame/validate/validate2085.tfrecord',
#  'yt8m/3/frame/validate/validate3140.tfrecord',
#  'yt8m/3/frame/validate/validate3649.tfrecord',
#  'yt8m/3/frame/validate/validate3252.tfrecord',
#  'yt8m/3/frame/validate/validate3087.tfrecord',
#  'yt8m/3/frame/validate/validate2030.tfrecord',
#  'yt8m/3/frame/validate/validate1055.tfrecord',
#  'yt8m/3/frame/validate/validate1566.tfrecord',
#  'yt8m/3/frame/validate/validate3430.tfrecord',
#  'yt8m/3/frame/validate/validate2451.tfrecord',
#  'yt8m/3/frame/validate/validate2519.tfrecord',
#  'yt8m/3/frame/validate/validate2386.tfrecord',
#  'yt8m/3/frame/validate/validate2746.tfrecord',
#  'yt8m/3/frame/validate/validate2230.tfrecord',
#  'yt8m/3/frame/validate/validate2196.tfrecord',
#  'yt8m/3/frame/validate/validate3266.tfrecord',
#  'yt8m/3/frame/validate/validate2516.tfrecord',
#  'yt8m/3/frame/validate/validate2260.tfrecord',
#  'yt8m/3/frame/validate/validate2189.tfrecord',
#  'yt8m/3/frame/validate/validate3343.tfrecord',
#  'yt8m/3/frame/validate/validate0505.tfrecord',
#  'yt8m/3/frame/validate/validate3486.tfrecord',
#  'yt8m/3/frame/validate/validate3555.tfrecord',
#  'yt8m/3/frame/validate/validate0425.tfrecord',
#  'yt8m/3/frame/validate/validate0968.tfrecord',
#  'yt8m/3/frame/validate/validate2180.tfrecord',
#  'yt8m/3/frame/validate/validate0717.tfrecord',
#  'yt8m/3/frame/validate/validate0765.tfrecord',
#  'yt8m/3/frame/validate/validate3365.tfrecord',
#  'yt8m/3/frame/validate/validate2642.tfrecord',
#  'yt8m/3/frame/validate/validate1930.tfrecord',
#  'yt8m/3/frame/validate/validate0095.tfrecord',
#  'yt8m/3/frame/validate/validate3099.tfrecord',
#  'yt8m/3/frame/validate/validate0837.tfrecord',
#  'yt8m/3/frame/validate/validate1541.tfrecord',
#  'yt8m/3/frame/validate/validate1853.tfrecord',
#  'yt8m/3/frame/validate/validate1334.tfrecord',
#  'yt8m/3/frame/validate/validate2730.tfrecord',
#  'yt8m/3/frame/validate/validate2552.tfrecord',
#  'yt8m/3/frame/validate/validate1430.tfrecord',
#  'yt8m/3/frame/validate/validate0518.tfrecord',
#  'yt8m/3/frame/validate/validate2871.tfrecord',
#  'yt8m/3/frame/validate/validate1844.tfrecord',
#  'yt8m/3/frame/validate/validate1207.tfrecord',
#  'yt8m/3/frame/validate/validate0758.tfrecord',
#  'yt8m/3/frame/validate/validate2150.tfrecord',
#  'yt8m/3/frame/validate/validate1646.tfrecord',
#  'yt8m/3/frame/validate/validate2790.tfrecord',
#  'yt8m/3/frame/validate/validate1890.tfrecord',
#  'yt8m/3/frame/validate/validate2852.tfrecord',
#  'yt8m/3/frame/validate/validate1300.tfrecord',
#  'yt8m/3/frame/validate/validate1262.tfrecord',
#  'yt8m/3/frame/validate/validate1329.tfrecord',
#  'yt8m/3/frame/validate/validate2304.tfrecord',
#  'yt8m/3/frame/validate/validate0021.tfrecord',
#  'yt8m/3/frame/validate/validate2320.tfrecord',
#  'yt8m/3/frame/validate/validate3359.tfrecord',
#  'yt8m/3/frame/validate/validate2973.tfrecord',
#  'yt8m/3/frame/validate/validate0502.tfrecord',
#  'yt8m/3/frame/validate/validate0981.tfrecord',
#  'yt8m/3/frame/validate/validate3128.tfrecord',
#  'yt8m/3/frame/validate/validate3644.tfrecord',
#  'yt8m/3/frame/validate/validate3318.tfrecord',
#  'yt8m/3/frame/validate/validate3534.tfrecord',
#  'yt8m/3/frame/validate/validate1400.tfrecord',
#  'yt8m/3/frame/validate/validate2728.tfrecord',
#  'yt8m/3/frame/validate/validate1352.tfrecord',
#  'yt8m/3/frame/validate/validate1514.tfrecord',
#  'yt8m/3/frame/validate/validate2212.tfrecord',
#  'yt8m/3/frame/validate/validate0946.tfrecord',
#  'yt8m/3/frame/validate/validate0947.tfrecord',
#  'yt8m/3/frame/validate/validate1037.tfrecord',
#  'yt8m/3/frame/validate/validate1495.tfrecord',
#  'yt8m/3/frame/validate/validate3249.tfrecord',
#  'yt8m/3/frame/validate/validate1863.tfrecord',
#  'yt8m/3/frame/validate/validate3055.tfrecord',
#  'yt8m/3/frame/validate/validate3718.tfrecord',
#  'yt8m/3/frame/validate/validate2825.tfrecord',
#  'yt8m/3/frame/validate/validate2940.tfrecord',
#  'yt8m/3/frame/validate/validate2918.tfrecord',
#  'yt8m/3/frame/validate/validate0252.tfrecord',
#  'yt8m/3/frame/validate/validate3108.tfrecord',
#  'yt8m/3/frame/validate/validate0302.tfrecord',
#  'yt8m/3/frame/validate/validate0601.tfrecord',
#  'yt8m/3/frame/validate/validate2343.tfrecord',
#  'yt8m/3/frame/validate/validate3475.tfrecord',
#  'yt8m/3/frame/validate/validate1792.tfrecord',
#  'yt8m/3/frame/validate/validate0975.tfrecord',
#  'yt8m/3/frame/validate/validate3384.tfrecord',
#  'yt8m/3/frame/validate/validate2729.tfrecord',
#  'yt8m/3/frame/validate/validate0483.tfrecord',
#  'yt8m/3/frame/validate/validate2673.tfrecord',
#  'yt8m/3/frame/validate/validate0992.tfrecord',
#  'yt8m/3/frame/validate/validate3263.tfrecord',
#  'yt8m/3/frame/validate/validate0672.tfrecord',
#  'yt8m/3/frame/validate/validate2780.tfrecord',
#  'yt8m/3/frame/validate/validate0647.tfrecord',
#  'yt8m/3/frame/validate/validate3625.tfrecord',
#  'yt8m/3/frame/validate/validate2257.tfrecord',
#  'yt8m/3/frame/validate/validate1660.tfrecord',
#  'yt8m/3/frame/validate/validate2269.tfrecord',
#  'yt8m/3/frame/validate/validate2166.tfrecord',
#  'yt8m/3/frame/validate/validate0401.tfrecord',
#  'yt8m/3/frame/validate/validate3818.tfrecord',
#  'yt8m/3/frame/validate/validate1231.tfrecord',
#  'yt8m/3/frame/validate/validate1954.tfrecord',
#  'yt8m/3/frame/validate/validate3746.tfrecord',
#  'yt8m/3/frame/validate/validate1440.tfrecord',
#  'yt8m/3/frame/validate/validate0942.tfrecord',
#  'yt8m/3/frame/validate/validate3702.tfrecord',
#  'yt8m/3/frame/validate/validate1168.tfrecord',
#  'yt8m/3/frame/validate/validate3336.tfrecord',
#  'yt8m/3/frame/validate/validate3811.tfrecord',
#  'yt8m/3/frame/validate/validate2117.tfrecord',
#  'yt8m/3/frame/validate/validate1297.tfrecord',
#  'yt8m/3/frame/validate/validate1449.tfrecord',
#  'yt8m/3/frame/validate/validate0300.tfrecord',
#  'yt8m/3/frame/validate/validate1595.tfrecord',
#  'yt8m/3/frame/validate/validate0536.tfrecord',
#  'yt8m/3/frame/validate/validate1158.tfrecord',
#  'yt8m/3/frame/validate/validate2315.tfrecord',
#  'yt8m/3/frame/validate/validate0342.tfrecord',
#  'yt8m/3/frame/validate/validate2203.tfrecord',
#  'yt8m/3/frame/validate/validate0783.tfrecord',
#  'yt8m/3/frame/validate/validate1923.tfrecord',
#  'yt8m/3/frame/validate/validate1210.tfrecord',
#  'yt8m/3/frame/validate/validate0494.tfrecord',
#  'yt8m/3/frame/validate/validate0884.tfrecord',
#  'yt8m/3/frame/validate/validate0654.tfrecord',
#  'yt8m/3/frame/validate/validate1934.tfrecord',
#  'yt8m/3/frame/validate/validate0266.tfrecord',
#  'yt8m/3/frame/validate/validate1444.tfrecord',
#  'yt8m/3/frame/validate/validate3469.tfrecord',
#  'yt8m/3/frame/validate/validate2637.tfrecord',
#  'yt8m/3/frame/validate/validate2029.tfrecord',
#  'yt8m/3/frame/validate/validate1809.tfrecord',
#  'yt8m/3/frame/validate/validate1602.tfrecord',
#  'yt8m/3/frame/validate/validate1082.tfrecord',
#  'yt8m/3/frame/validate/validate3668.tfrecord',
#  'yt8m/3/frame/validate/validate3235.tfrecord',
#  'yt8m/3/frame/validate/validate1741.tfrecord',
#  'yt8m/3/frame/validate/validate3355.tfrecord',
#  'yt8m/3/frame/validate/validate0728.tfrecord',
#  'yt8m/3/frame/validate/validate1104.tfrecord',
#  'yt8m/3/frame/validate/validate2817.tfrecord',
#  'yt8m/3/frame/validate/validate1227.tfrecord',
#  'yt8m/3/frame/validate/validate0540.tfrecord',
#  'yt8m/3/frame/validate/validate0533.tfrecord',
#  'yt8m/3/frame/validate/validate0164.tfrecord',
#  'yt8m/3/frame/validate/validate0340.tfrecord',
#  'yt8m/3/frame/validate/validate1123.tfrecord',
#  'yt8m/3/frame/validate/validate1085.tfrecord',
#  'yt8m/3/frame/validate/validate2336.tfrecord',
#  'yt8m/3/frame/validate/validate1908.tfrecord',
#  'yt8m/3/frame/validate/validate0495.tfrecord',
#  'yt8m/3/frame/validate/validate0403.tfrecord',
#  'yt8m/3/frame/validate/validate3454.tfrecord',
#  'yt8m/3/frame/validate/validate1091.tfrecord',
#  'yt8m/3/frame/validate/validate1835.tfrecord',
#  'yt8m/3/frame/validate/validate2636.tfrecord',
#  'yt8m/3/frame/validate/validate0774.tfrecord',
#  'yt8m/3/frame/validate/validate0257.tfrecord',
#  'yt8m/3/frame/validate/validate2194.tfrecord',
#  'yt8m/3/frame/validate/validate0553.tfrecord',
#  'yt8m/3/frame/validate/validate2834.tfrecord',
#  'yt8m/3/frame/validate/validate2139.tfrecord',
#  'yt8m/3/frame/validate/validate0050.tfrecord',
#  'yt8m/3/frame/validate/validate3623.tfrecord',
#  'yt8m/3/frame/validate/validate0971.tfrecord',
#  'yt8m/3/frame/validate/validate2486.tfrecord',
#  'yt8m/3/frame/validate/validate0732.tfrecord',
#  'yt8m/3/frame/validate/validate0415.tfrecord',
#  'yt8m/3/frame/validate/validate2495.tfrecord',
#  'yt8m/3/frame/validate/validate3637.tfrecord',
#  'yt8m/3/frame/validate/validate1977.tfrecord',
#  'yt8m/3/frame/validate/validate0359.tfrecord',
#  'yt8m/3/frame/validate/validate0220.tfrecord',
#  'yt8m/3/frame/validate/validate3044.tfrecord',
#  'yt8m/3/frame/validate/validate0167.tfrecord',
#  'yt8m/3/frame/validate/validate0775.tfrecord',
#  'yt8m/3/frame/validate/validate0836.tfrecord',
#  'yt8m/3/frame/validate/validate0303.tfrecord',
#  'yt8m/3/frame/validate/validate2710.tfrecord',
#  'yt8m/3/frame/validate/validate0405.tfrecord',
#  'yt8m/3/frame/validate/validate1110.tfrecord',
#  'yt8m/3/frame/validate/validate1684.tfrecord',
#  'yt8m/3/frame/validate/validate0501.tfrecord',
#  'yt8m/3/frame/validate/validate1359.tfrecord',
#  'yt8m/3/frame/validate/validate0910.tfrecord',
#  'yt8m/3/frame/validate/validate3646.tfrecord',
#  'yt8m/3/frame/validate/validate3792.tfrecord',
#  'yt8m/3/frame/validate/validate0358.tfrecord',
#  'yt8m/3/frame/validate/validate2580.tfrecord',
#  'yt8m/3/frame/validate/validate1946.tfrecord',
#  'yt8m/3/frame/validate/validate1347.tfrecord',
#  'yt8m/3/frame/validate/validate2700.tfrecord',
#  'yt8m/3/frame/validate/validate2274.tfrecord',
#  'yt8m/3/frame/validate/validate1643.tfrecord',
#  'yt8m/3/frame/validate/validate1528.tfrecord',
#  'yt8m/3/frame/validate/validate0293.tfrecord',
#  'yt8m/3/frame/validate/validate0658.tfrecord',
#  'yt8m/3/frame/validate/validate3192.tfrecord',
#  'yt8m/3/frame/validate/validate2645.tfrecord',
#  'yt8m/3/frame/validate/validate0136.tfrecord',
#  'yt8m/3/frame/validate/validate2705.tfrecord',
#  'yt8m/3/frame/validate/validate3391.tfrecord',
#  'yt8m/3/frame/validate/validate1419.tfrecord',
#  'yt8m/3/frame/validate/validate2763.tfrecord',
#  'yt8m/3/frame/validate/validate2411.tfrecord',
#  'yt8m/3/frame/validate/validate1339.tfrecord',
#  'yt8m/3/frame/validate/validate3493.tfrecord',
#  'yt8m/3/frame/validate/validate1873.tfrecord',
#  'yt8m/3/frame/validate/validate1935.tfrecord',
#  'yt8m/3/frame/validate/validate1065.tfrecord',
#  'yt8m/3/frame/validate/validate2743.tfrecord',
#  'yt8m/3/frame/validate/validate2725.tfrecord',
#  'yt8m/3/frame/validate/validate2215.tfrecord',
#  'yt8m/3/frame/validate/validate1812.tfrecord',
#  'yt8m/3/frame/validate/validate2814.tfrecord',
#  'yt8m/3/frame/validate/validate0926.tfrecord',
#  'yt8m/3/frame/validate/validate2676.tfrecord',
#  'yt8m/3/frame/validate/validate2801.tfrecord',
#  'yt8m/3/frame/validate/validate0682.tfrecord',
#  'yt8m/3/frame/validate/validate3159.tfrecord',
#  'yt8m/3/frame/validate/validate3037.tfrecord',
#  'yt8m/3/frame/validate/validate3624.tfrecord',
#  'yt8m/3/frame/validate/validate1941.tfrecord',
#  'yt8m/3/frame/validate/validate1281.tfrecord',
#  'yt8m/3/frame/validate/validate1289.tfrecord',
#  'yt8m/3/frame/validate/validate1523.tfrecord',
#  'yt8m/3/frame/validate/validate3767.tfrecord',
#  'yt8m/3/frame/validate/validate2152.tfrecord',
#  'yt8m/3/frame/validate/validate3386.tfrecord',
#  'yt8m/3/frame/validate/validate3573.tfrecord',
#  'yt8m/3/frame/validate/validate2040.tfrecord',
#  'yt8m/3/frame/validate/validate2477.tfrecord',
#  'yt8m/3/frame/validate/validate3337.tfrecord',
#  'yt8m/3/frame/validate/validate1257.tfrecord',
#  'yt8m/3/frame/validate/validate0292.tfrecord',
#  'yt8m/3/frame/validate/validate1978.tfrecord',
#  'yt8m/3/frame/validate/validate2007.tfrecord',
#  'yt8m/3/frame/validate/validate0187.tfrecord',
#  'yt8m/3/frame/validate/validate3073.tfrecord',
#  'yt8m/3/frame/validate/validate2778.tfrecord',
#  'yt8m/3/frame/validate/validate2555.tfrecord',
#  'yt8m/3/frame/validate/validate2644.tfrecord',
#  'yt8m/3/frame/validate/validate1609.tfrecord',
#  'yt8m/3/frame/validate/validate1958.tfrecord',
#  'yt8m/3/frame/validate/validate2359.tfrecord',
#  'yt8m/3/frame/validate/validate3713.tfrecord',
#  'yt8m/3/frame/validate/validate3514.tfrecord',
#  'yt8m/3/frame/validate/validate2903.tfrecord',
#  'yt8m/3/frame/validate/validate2935.tfrecord',
#  'yt8m/3/frame/validate/validate0764.tfrecord',
#  'yt8m/3/frame/validate/validate2896.tfrecord',
#  'yt8m/3/frame/validate/validate0922.tfrecord',
#  'yt8m/3/frame/validate/validate1124.tfrecord',
#  'yt8m/3/frame/validate/validate1707.tfrecord',
#  'yt8m/3/frame/validate/validate0716.tfrecord',
#  'yt8m/3/frame/validate/validate1645.tfrecord',
#  'yt8m/3/frame/validate/validate1924.tfrecord',
#  'yt8m/3/frame/validate/validate2499.tfrecord',
#  'yt8m/3/frame/validate/validate1152.tfrecord',
#  'yt8m/3/frame/validate/validate2485.tfrecord',
#  'yt8m/3/frame/validate/validate0433.tfrecord',
#  'yt8m/3/frame/validate/validate2855.tfrecord',
#  'yt8m/3/frame/validate/validate1535.tfrecord',
#  'yt8m/3/frame/validate/validate0384.tfrecord',
#  'yt8m/3/frame/validate/validate2955.tfrecord',
#  'yt8m/3/frame/validate/validate0454.tfrecord',
#  'yt8m/3/frame/validate/validate0628.tfrecord',
#  'yt8m/3/frame/validate/validate0453.tfrecord',
#  'yt8m/3/frame/validate/validate2414.tfrecord',
#  'yt8m/3/frame/validate/validate2785.tfrecord',
#  'yt8m/3/frame/validate/validate1242.tfrecord',
#  'yt8m/3/frame/validate/validate3079.tfrecord',
#  'yt8m/3/frame/validate/validate0400.tfrecord',
#  'yt8m/3/frame/validate/validate0506.tfrecord',
#  'yt8m/3/frame/validate/validate0979.tfrecord',
#  'yt8m/3/frame/validate/validate2734.tfrecord',
#  'yt8m/3/frame/validate/validate1572.tfrecord',
#  'yt8m/3/frame/validate/validate1701.tfrecord',
#  'yt8m/3/frame/validate/validate0959.tfrecord',
#  'yt8m/3/frame/validate/validate1111.tfrecord',
#  'yt8m/3/frame/validate/validate1788.tfrecord',
#  'yt8m/3/frame/validate/validate1508.tfrecord',
#  'yt8m/3/frame/validate/validate2872.tfrecord',
#  'yt8m/3/frame/validate/validate0853.tfrecord',
#  'yt8m/3/frame/validate/validate0480.tfrecord',
#  'yt8m/3/frame/validate/validate1551.tfrecord',
#  'yt8m/3/frame/validate/validate2598.tfrecord',
#  'yt8m/3/frame/validate/validate1793.tfrecord',
#  'yt8m/3/frame/validate/validate1944.tfrecord',
#  'yt8m/3/frame/validate/validate1253.tfrecord',
#  'yt8m/3/frame/validate/validate1546.tfrecord',
#  'yt8m/3/frame/validate/validate0881.tfrecord',
#  'yt8m/3/frame/validate/validate0195.tfrecord',
#  'yt8m/3/frame/validate/validate2724.tfrecord',
#  'yt8m/3/frame/validate/validate0684.tfrecord',
#  'yt8m/3/frame/validate/validate3122.tfrecord',
#  'yt8m/3/frame/validate/validate1351.tfrecord',
#  'yt8m/3/frame/validate/validate3676.tfrecord',
#  'yt8m/3/frame/validate/validate3641.tfrecord',
#  'yt8m/3/frame/validate/validate2316.tfrecord',
#  'yt8m/3/frame/validate/validate1870.tfrecord',
#  'yt8m/3/frame/validate/validate1503.tfrecord',
#  'yt8m/3/frame/validate/validate0573.tfrecord',
#  'yt8m/3/frame/validate/validate0193.tfrecord',
#  'yt8m/3/frame/validate/validate0343.tfrecord',
#  ...]

# %%
raw_dataset = tf.data.TFRecordDataset(files)

# %%
A_SZ, V_SZ, L_SZ = 128,1024,303
SZ= int(2e7)

a = torch.empty((SZ,A_SZ), dtype=torch.uint8) # audio
v = torch.empty((SZ,V_SZ), dtype=torch.uint8) # video
d = dict()

# %%
def mmap_bytetensor(f, shape, shared=False,size=None):
    return torch.ByteTensor(
        torch.ByteStorage.from_file(f, shared=shared, size=size if size is not None else os.path.getsize(f))).view(*shape)

# %%
i_f = i_av = 0
TOTAL = 47073
for i,raw_record in enumerate(progress_bar(raw_dataset.take(-1), total=TOTAL)):
        
    example = tf.train.SequenceExample()
    example.ParseFromString(raw_record.numpy())
    labels = list(example.context.feature['labels'].int64_list.value)
    vid    = str(example.context.feature['id'].bytes_list.value[0].decode(encoding='UTF-8'))
    audio  = torch.ByteTensor(
        [np.frombuffer(f.bytes_list.value[0], dtype=np.uint8) for f in example.feature_lists.feature_list['audio'].feature])
    video  = torch.ByteTensor(
        [np.frombuffer(f.bytes_list.value[0], dtype=np.uint8) for f in example.feature_lists.feature_list['rgb'].feature])
    frames = len(audio)
    segments = list(zip(*[getattr(example.context.feature[f],t).value for f,t in [('segment_labels','int64_list'), 
        ('segment_scores','float_list'), ('segment_start_times','int64_list'),('segment_end_times','int64_list')]]))

    assert frames == len(video)
    assert frames <= L_SZ
    d[vid] = (i_av, frames, labels, segments)
    a[i_av:i_av+frames] = audio
    v[i_av:i_av+frames] = video
    del audio, video, labels, segments
    i_av += frames

    if ((i_av + L_SZ)>= SZ) or (i==TOTAL-1):
        print(f'Saving {i_f} at {i}')
        aw = mmap_bytetensor(f'{OUT_PATH}/val_a{i_f}.bin',(-1,A_SZ),  shared=True, size=i_av*A_SZ)
        vw = mmap_bytetensor(f'{OUT_PATH}/val_v{i_f}.bin',(-1,V_SZ),  shared=True, size=i_av*V_SZ)
        
        aw[:] = a[:i_av]
        vw[:] = v[:i_av]
        with open(f'{OUT_PATH}/val_d{i_f}.pkl', 'wb') as handle:
            pickle.dump(d, handle, protocol=pickle.HIGHEST_PROTOCOL)
        d = dict()
        i_av = 0
        i_f += 1
        del aw,vw

    if i == 2:
        break
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='47073', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>

# %%
d
# Out:
# {'vgqO': (0,
#   188,
#   [146, 158, 439, 454],
#   [(279, 0.0, 115, 120),
#    (279, 0.0, 145, 150),
#    (279, 0.0, 90, 95),
#    (279, 0.0, 150, 155),
#    (279, 0.0, 55, 60)]),
#  'O6qO': (188,
#   152,
#   [6, 8, 414],
#   [(414, 0.0, 105, 110),
#    (414, 1.0, 35, 40),
#    (414, 1.0, 100, 105),
#    (414, 1.0, 65, 70),
#    (414, 0.0, 80, 85)]),
#  'OLqO': (340,
#   228,
#   [2, 44, 46, 107, 109, 114, 162, 854, 1164],
#   [(854, 0.0, 180, 185),
#    (1164, 0.0, 185, 190),
#    (854, 0.0, 30, 35),
#    (1164, 1.0, 75, 80),
#    (1164, 1.0, 65, 70),
#    (1164, 1.0, 40, 45),
#    (854, 0.0, 130, 135),
#    (1164, 0.0, 140, 145),
#    (854, 0.0, 185, 190)])}

# %%
# Out:
# [(279, 0.0, 115, 120),
#  (279, 0.0, 145, 150),
#  (279, 0.0, 90, 95),
#  (279, 0.0, 150, 155),
#  (279, 0.0, 55, 60)]

# %%
ifnone(v.numel(), 10)

# %%
for i in progress_bar(range(1,89)): # 89
    a = torch.load(f'{OUT_PATH}/a{i}.pth')
    aw = mmap_bytetensor(f'{OUT_PATH}/a{i}.bin',(-1,128),  shared=True, size=a.numel())
    aw[:] = a
    v = torch.load(f'{OUT_PATH}/v{i}.pth')
    vw = mmap_bytetensor(f'{OUT_PATH}/v{i}.bin',(-1,1024), shared=True, size=v.numel())
    vw[:] = v
    os.remove(f'{OUT_PATH}/a{i}.pth')
    os.remove(f'{OUT_PATH}/v{i}.pth')

# %%
vvw=read_bytetensor('yt8m-processed/v0.bin', (-1,1024))

# %%
n = 89
[read_bytetensor(f'yt8m-processed/v{i}.bin', (-1,1024)) for i in range(n)]
